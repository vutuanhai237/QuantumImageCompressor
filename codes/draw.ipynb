# %%
import sys
sys.path.insert(0, '..')
from qoop.compilation.qsp import QuantumStatePreparation
from qoop.core import state, ansatz
from qoop.compilation import compress
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %load_ext autoreload
# %autoreload 2

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit.providers.basicaer import QasmSimulatorPy 
from qiskit import transpile
qc = state.specific(np.random.uniform(0, 2*np.pi, 2**3))
# transpile circuit by QASM simulator

qc1 = transpile(qc, QasmSimulatorPy()).inverse()
qc1.draw('mpl', filename = 'qasm', scale = 5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
ansatz.g2gn(3, 1).draw('mpl', filename='g2.png', scale = 10)
